# %% [markdown]
# <a href="https://colab.research.google.com/github/xochi7l/hello-world/blob/main/Final_Project_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# "Ransomware is a malware designed to deny a user or organization
# access to files on their computer. By encrypting these files and
# demanding a ransom payment for the decryption key, cyberattackers
# place organizations in a position where paying the ransom is the
# easiest and cheapest way to regain access to their files."'

# Ransomware samples attempt to encode and decode base64 format and
# share memory pages with other processes.
    # so maybe we should look closer at memory processes for statistical significance???

# Rebooting
# In this work, it is found that some malware samples are executed only after
# rebooting the emulator. After analyzing malware samples and extracting
# dynamic characteristics, the emulator is rebooted and the process is repeated
# from the beginning to capture dynamic characteristics again.

ransomwareBefore = pd.read_csv(r"/content/AndMal2020-dynamic-BeforeAndAfterReboot/Ransomware_before_reboot_Cat.csv")
ransomwareAfter = pd.read_csv(r"/content/AndMal2020-dynamic-BeforeAndAfterReboot/Ransomware_after_reboot_Cat.csv")

# %%
# Areas that may be of interest:
# Memory - features define activities performed by malware by utilizing memory. <--------
# App Programming Interface (API) - features delineate the communication between two applications.
# Network - features describe the data transmitted and received between other devices in the network.
#           It indicates foreground and background network usage.
# Battery - features describe the access to battery wakelock and services by malware
# Logcat - features write log messages corresponding to a function performed by malware <--------
# Process - features count the interaction of malware with total number of processes. <--------

# There are six major entropy value changes in koler, lockscreen, congur, masnu, jisut, and slocker families.
# Koler loads URLs and adds web interfaces, gets device Id, SIM serial number and system properties.
# Lockscreen, congur, slocker, and jisut obtain system properties and API sessions.
# Masnu accesses database and executes queries. Additionally, it updates message digest and identifies secret key.



#print(ransomwareBefore)
#print(fransomwareAfter)

# %%
# Memory - features define activities performed by malware by utilizing memory.
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Memory_PssTotal', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 0.00005)
sns.displot(data = ransomwareAfter, x='Memory_PssTotal', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 0.00005)
# Out:
# (0.0, 5e-05)

# %%
# App Programming Interface (API) - features delineate the communication between two applications.
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='API__sessions', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 0.14)
sns.displot(data = ransomwareAfter, x='API__sessions', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 0.14)
# Out:
# (0.0, 0.14)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='API__sessions', hue = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, hue_order = myVector).set(title='API Before Reboot')
plt.ylim(0, 0.25)
sns.displot(data = ransomwareAfter, x='API__sessions', hue = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, hue_order = myVector).set(title='API After Reboot')
plt.ylim(0, 0.25)
# Out:
# (0.0, 0.25)

# %%
# Battery - features describe the access to battery wakelock and services by malware
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Battery_wakelock', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 1)
sns.displot(data = ransomwareAfter, x='Battery_wakelock', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 1)

# VERY INTERESTING, why would there be MORE instances of access to the battery wakelock
# by ransomeware after a reboot?? In all other categories processes decrease after a reboot.
# Out:
# (0.0, 1.0)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Battery_service', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 1.5)
sns.displot(data = ransomwareAfter, x='Battery_service', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, 1.5)
# Out:
# (0.0, 1.5)

# %%
# Logcat - features write log messages corresponding to a function performed by malware
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Logcat_warning', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)
sns.displot(data = ransomwareAfter, x='Logcat_warning', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)

# Warnings corresponding to fuctions performed by the malware fall off more
# significantly after a reboot than the other logcat messages.
# Out:
# (0.0, 0.000175)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Logcat_error', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)
sns.displot(data = ransomwareAfter, x='Logcat_error', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Logcat_debug', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)
sns.displot(data = ransomwareAfter, x='Logcat_debug', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)
# Out:
# (0.0, 0.000175)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Logcat_verbose', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)
sns.displot(data = ransomwareAfter, x='Logcat_verbose', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Logcat_info', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)
sns.displot(data = ransomwareAfter, x='Logcat_info', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .000175)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Logcat_total', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .0001)
sns.displot(data = ransomwareAfter, x='Logcat_total', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .0001)

# Generally, Logact messages corresponding to a function performed by malware decrease after a reboot.
# So less functions performed by the ransomeware after a reboot overall?
# Out:
# (0.0, 0.0001)

# %%
# Process - features count the interaction of malware with total number of processes.
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Process_total', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .130)
sns.displot(data = ransomwareAfter, x='Process_total', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .130)

# not effected by the rebot at all...
# Out:
# (0.0, 0.13)

# %%
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Process_total', hue = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, hue_order = myVector).set(title='Total Processes Before Reboot')
plt.ylim(0, 0.3)
sns.displot(data = ransomwareAfter, x='Process_total', hue = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, hue_order = myVector).set(title='Totoal Processes After Reboot')
plt.ylim(0, 0.3)
# Out:
# (0.0, 0.3)

# %%
ransom_before_dummy = ransomwareBefore
ransom_before_dummy['After'] = 0
ransom_after_dummy = ransomwareAfter
ransom_after_dummy['After'] = 1
ransom_dummy = pd.concat([ransom_before_dummy, ransom_after_dummy])
ransom_dummy.drop(['Hash', 'Category'], axis = 1)

## Use a logistic regression to test whether or not a reboot has occurred
##logistic since before/after is a binary, categorical variable. It is not possible to be both or neither in the context of the data



## <i>Syntax</i> for the following was found through scikit-learn.org, stack-overflow, and GPT-4



from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler


X = ransom_dummy.loc[:, 'Memory_PssTotal':'Process_total']
##Dropping all columns that have no data (i.e. around half of the API columns)
for col in X:
  if (X[col].sum() <= 0):
    X.drop(col, inplace = True, axis = 1)


y = ransom_dummy['After'].values

## Set the random state for reproducability and standardize as to not favor one feature ove another
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 25)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)




model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy*100:.2f}%')

##since random state was set accuracy should be around 93-95%

# %%
## displaying the actual equation
## This likely uses too many features and will have issues with overexplaining the data. Not quite collinearity but close

## To get stat significance need to use statsmodels.api, which I haven't been able to figure out yet. Will continue to look


intercept = model.intercept_[0]
coeff = model.coef_[0]
equation = f'logit(p) = {intercept:.4f} + '
for i, coef in enumerate(coeff):
  equation +=f'({coef:.4f}) * feature_(i +1) + '
print(equation)

##however seeing the graph here shows which features have the greatest impact on before/after
##should show that (around) first 10 features (i.e. Memory features) affect model most
##This does not show statistical significance however

plt.plot(coeff)
# Out:
# logit(p) = -1.2288 + (-3.9538) * feature_(i +1) + (-2.0749) * feature_(i +1) + (-0.2437) * feature_(i +1) + (3.5071) * feature_(i +1) + (2.0455) * feature_(i +1) + (3.2433) * feature_(i +1) + (0.0519) * feature_(i +1) + (0.0601) * feature_(i +1) + (-0.0020) * feature_(i +1) + (0.0814) * feature_(i +1) + (-0.0399) * feature_(i +1) + (0.0779) * feature_(i +1) + (0.5585) * feature_(i +1) + (-0.0570) * feature_(i +1) + (1.0467) * feature_(i +1) + (-2.1188) * feature_(i +1) + (-0.0466) * feature_(i +1) + (-0.0533) * feature_(i +1) + (0.1474) * feature_(i +1) + (-0.0106) * feature_(i +1) + (0.0845) * feature_(i +1) + (1.4753) * feature_(i +1) + (0.0366) * feature_(i +1) + (-0.0922) * feature_(i +1) + (-0.5242) * feature_(i +1) + (0.0672) * feature_(i +1) + (-0.0012) * feature_(i +1) + (-0.0848) * feature_(i +1) + (0.1237) * feature_(i +1) + (0.0403) * feature_(i +1) + (-0.3436) * feature_(i +1) + (-0.0645) * feature_(i +1) + (0.1700) * feature_(i +1) + (-0.5068) * feature_(i +1) + (-0.5068
# ...

# %%
#https://developer.android.com/topic/performance/memory-management
#Private: Owned by one process and not shared
#Clean: Unmodified copy of a file on storage
#Dirty: Modified copy of the file on storage
#Shared: Used by multiple processes
#Clean: Unmodified copy of the file on storage,
#Dirty: Modified copy of the file on storage;
#Proportional Set Size (PSS): The number of non-shared pages used by the app and an even distribution of the shared pages (for example, if three processes are sharing 3MB, each process gets 1MB in PSS)
#PSS is useful for the operating system when it wants to know how much memory is used by all processes since pages don’t get counted multiple times.
#PSS takes a long time to calculate because the system needs to determine which pages are shared and by how many processes.

#https://developer.android.com/guide/topics/security/cryptography
#https://developer.android.com/reference/javax/crypto/Cipher
#https://developer.android.com/reference/javax/crypto/spec/SecretKeySpec
#API_Crypto_javax.crypto.spec.SecretKeySpec_$init
#Is this the pre-ecryption process?
#Answer:This class specifies a secret key in a provider-independent fashion. It can be used to construct a SecretKey from a byte array, without having to go through a (provider-based) SecretKeyFactory
#"init" = The cipher is initialized for one of the following four operations: encryption, decryption, key wrapping or key unwrapping, depending on the value of opmode
#API_Crypto_javax.crypto.Cipher_doFinal
#Is this the actual encryption process?
#Answer: Encrypts or decrypts data in a single-part operation, or finishes a multiple-part operation

# %%
# Memory (Private Dirty) - Modified memory exclusive to this malware (modified copy of the file on storage, owned by one process and not shared)
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Memory_PrivateDirty', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .00006)
sns.displot(data = ransomwareAfter, x='Memory_PrivateDirty', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .00006)

# comments: change x,y limits.
# Do some families use more memory than others?
# Out:
# (0.0, 6e-05)

# %%
# Pre-encryption processes (constructs a "SecretKey" and initializes one of the four encryption operations). Does rebooting your device disrupt encryption processes?
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='API_Crypto_javax.crypto.spec.SecretKeySpec_$init', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .035)
sns.displot(data = ransomwareAfter, x='API_Crypto_javax.crypto.spec.SecretKeySpec_$init', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .035)

# comments: change x,y limits. Unsure if this is truly a pre-encryption process, and if malware samples were allowed to perform encryption processes during dynamic analysis
# Out:
# (0.0, 0.035)

# %%
# Encryption processes (Encrypts or decrypts data in a single-part operation, or finishes a multiple-part operation). Does rebooting your device disrupt encryption processes?
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='API_Crypto_javax.crypto.Cipher_doFinal', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .03)
sns.displot(data = ransomwareAfter, x='API_Crypto_javax.crypto.Cipher_doFinal', hue = 'Family', col = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, col_order = myVector)
plt.ylim(0, .03)

# comments: change x,y limits. Unsure if this is truly an encryption process, and if malware samples were allowed to perform encryption processes during dynamic analysis
# Out:
# (0.0, 0.03)

# %%
#Worth noting the i/o rate on the network
#For example:
# Network_TotalReceivedPackets vs Network_TotalTransmittedPackets
#Question being: Does rebooting your device disrupt ransomware network communications?

# %%
#Another interesting analysis would be frequent i/o of network transmissions or some other unique ransomware behavior vs API_Command_java.lang.Runtime_exec
#If there are frequent processes in a short amount of time, then there may be cause for suspicion

# %%
# Alternative visuals for the battery wakelock
# Battery - features describe the access to battery wakelock and services by malware
myVector = (['slocker','jisut','congur','lockscreen','smsspy','<unknown>','koler','masnu'])
sns.displot(data = ransomwareBefore, x='Battery_wakelock', hue = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, hue_order = myVector).set(title='Battery Wakelock Before Reboot')
plt.ylim(0, 1.75)
sns.displot(data = ransomwareAfter, x='Battery_wakelock', hue = 'Family',kind = 'kde', multiple = 'stack',warn_singular=False, hue_order = myVector).set(title='Battery Wakelock After Reboot')
plt.ylim(0, 1.75)
# Out:
# (0.0, 1.75)

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
import os
import seaborn as sns

## Changeworking directory to where csvs are stored
os.chdir("C://Users/admin/OneDrive/Documents/College/CU Boulder/Sem1/Lecture Classes/5301/DynamicAnalysis/AndMal2020-dynamic-BeforeAndAfterReboot")

## upload csvs that contain before using a for loop so I can make a dummy for before and after reboot for comparisons (making a dummy column here)
before_files = [f for f in os.listdir() if '_before_' in f]
dfs = []
for csv in before_files:
    df = pd.read_csv(csv)
    dfs.append(df)
AndMal2020Before = pd.concat(dfs, ignore_index = True)
AndMal2020Before['After'] = 0
AndMal2020Before.head()


##Same thing but for after reboot
after_files = [f for f in os.listdir() if '_after_' in f]
dfs = []
for csv in after_files:
    df = pd.read_csv(csv)
    dfs.append(df)
AndMal2020After = pd.concat(dfs, ignore_index = True)
AndMal2020After['After'] = 1
AndMal2020After.head()


##Concatenating the two dataframes using concat so key is not necessary
AndMal2020 = pd.concat([AndMal2020Before, AndMal2020After], ignore_index= True)
AndMal2020.head()


##Looking at differences in before and after quantities (sums will provide me with the data to be used for graphing due to dummy present)
Category_sums = AndMal2020.groupby(['Category','After']).count()
print(Category_sums)
##(order total threats to properly order histogram see sns.catplot(order))
Category_sort = Category_sums.groupby('Category').sum()
Category_sorted = Category_sort['Memory_ParcelCount'].sort_values(ascending = False)


'''
Looking at the data we see that quantities of each type decrease after a reboot. Visualizations following will help to determing scale by which there
is a change, what is most affected by a reboot, etc. At a first glance, expect to see Trojan Spyware have the most drastice change before and after in <i>both</i>
total change (quantity) and percentage change.
'''

## Barplot showing before and after values of each category based on a reboot --- THIS one shows before and after next to one another
## I prefer it as it's easier to read the difference but the next one is prettier
ax = sns.catplot(data = Category_sums.reset_index(),
            x = "Category",
            y = 'Memory_PssTotal',
            hue = 'After',
            kind = 'bar',
            legend=False,
            order=['Riskware', 'Adware', 'Trojan', 'Zero_Day', 'Ransomware', 'Trojan_Spy', 'Trojan_SMS', 'No_Category', 'Trojan_Dropper', 'PUA', 'Backdoor', 'Scareware', 'FileInfector', 'Trojan_Banker']
            )
plt.xticks(rotation = 90)
plt.ylabel('Quantity')
plt.legend(title = 'Threats Present',
           loc = 'best'
           )
plt.title('Quantity of Threats Present Before(0) and After(1) Reboot')
plt.show()
